# %% [markdown]
# # 🔑 Python Classes - Exercise Solutions
#
# Solutions for all exercises from the practice guide.

# %% [markdown]
# ## Exercise 1: Basic Class

# %%
class Car:
    wheels = 4

car1 = Car()
car2 = Car()
print(f"car1 wheels: {car1.wheels}")
print(f"car2 wheels: {car2.wheels}")

# %% [markdown]
# ## Exercise 2: Constructor

# %%
class Book:
    def __init__(self, title, author, pages):
        self.title = title
        self.author = author
        self.pages = pages

book = Book("Python Mastery", "John Doe", 350)
print(f"Title: {book.title}")
print(f"Author: {book.author}")
print(f"Pages: {book.pages}")

# %% [markdown]
# ## Exercise 3: Instance vs Class Attributes

# %%
class Student:
    school_name = "ABC School"
    total_students = 0
    
    def __init__(self, name, grade):
        self.name = name
        self.grade = grade
        Student.total_students += 1

s1 = Student("Alice", "A")
s2 = Student("Bob", "B")
print(f"School: {Student.school_name}")
print(f"Total: {Student.total_students}")

# %% [markdown]
# ## Exercise 4: Instance Methods

# %%
class Rectangle:
    def __init__(self, width, height):
        self.width = width
        self.height = height
    
    def area(self):
        return self.width * self.height
    
    def perimeter(self):
        return 2 * (self.width + self.height)

rect = Rectangle(5, 3)
print(f"Area: {rect.area()}")
print(f"Perimeter: {rect.perimeter()}")

# %% [markdown]
# ## Exercise 5: Class & Static Methods

# %%
class Date:
    def __init__(self, day, month, year):
        self.day = day
        self.month = month
        self.year = year
    
    @classmethod
    def from_string(cls, date_string):
        day, month, year = map(int, date_string.split('-'))
        return cls(day, month, year)
    
    @staticmethod
    def is_valid_date(day, month, year):
        if month < 1 or month > 12:
            return False
        if day < 1 or day > 31:
            return False
        if year < 1:
            return False
        return True

d = Date.from_string("15-06-2024")
print(f"Date: {d.day}/{d.month}/{d.year}")
print(f"Valid? {Date.is_valid_date(31, 2, 2024)}")

# %% [markdown]
# ## Exercise 6: Inheritance

# %%
class Vehicle:
    def __init__(self, brand, model):
        self.brand = brand
        self.model = model

class Car(Vehicle):
    def __init__(self, brand, model, num_doors):
        super().__init__(brand, model)
        self.num_doors = num_doors

class Motorcycle(Vehicle):
    def __init__(self, brand, model, has_sidecar):
        super().__init__(brand, model)
        self.has_sidecar = has_sidecar

car = Car("Toyota", "Camry", 4)
bike = Motorcycle("Harley", "Sportster", False)
print(f"{car.brand} {car.model}: {car.num_doors} doors")
print(f"{bike.brand} {bike.model}: sidecar={bike.has_sidecar}")

# %% [markdown]
# ## Exercise 7: super() Function

# %%
import math

class Shape:
    def __init__(self, color):
        self.color = color
    
    def area(self):
        return 0

class Circle(Shape):
    def __init__(self, color, radius):
        super().__init__(color)
        self.radius = radius
    
    def area(self):
        return math.pi * self.radius ** 2

c = Circle("red", 5)
print(f"Color: {c.color}")
print(f"Area: {c.area():.2f}")

# %% [markdown]
# ## Exercise 8: Encapsulation

# %%
class Password:
    def __init__(self):
        self.__password = None
    
    def set_password(self, pwd):
        if len(pwd) >= 8:
            self.__password = pwd
            return True
        return False
    
    def check_password(self, pwd):
        return self.__password == pwd

p = Password()
print(f"Set 'abc': {p.set_password('abc')}")
print(f"Set 'securepass123': {p.set_password('securepass123')}")
print(f"Check: {p.check_password('securepass123')}")

# %% [markdown]
# ## Exercise 9: Properties

# %%
import math

class Circle:
    def __init__(self, radius):
        self._radius = radius
    
    @property
    def radius(self):
        return self._radius
    
    @radius.setter
    def radius(self, value):
        if value > 0:
            self._radius = value
        else:
            raise ValueError("Radius must be positive")
    
    @property
    def area(self):
        return math.pi * self._radius ** 2

c = Circle(5)
print(f"Radius: {c.radius}, Area: {c.area:.2f}")
c.radius = 10
print(f"New radius: {c.radius}, Area: {c.area:.2f}")

# %% [markdown]
# ## Exercise 10: Magic Methods

# %%
class Money:
    def __init__(self, amount, currency="USD"):
        self.amount = amount
        self.currency = currency
    
    def __str__(self):
        symbol = "$" if self.currency == "USD" else self.currency
        return f"{symbol}{self.amount:.2f}"
    
    def __add__(self, other):
        if self.currency != other.currency:
            raise ValueError("Cannot add different currencies")
        return Money(self.amount + other.amount, self.currency)
    
    def __eq__(self, other):
        return self.amount == other.amount and self.currency == other.currency

m1 = Money(100)
m2 = Money(50)
print(f"m1: {m1}")
print(f"m1 + m2: {m1 + m2}")
print(f"m1 == m2: {m1 == m2}")

# %% [markdown]
# ## Exercise 11: Multiple Inheritance

# %%
class Printable:
    def print_info(self):
        return f"Printing: {self.title}"

class Saveable:
    def save(self):
        return f"Saving: {self.title}"

class Document(Printable, Saveable):
    def __init__(self, title):
        self.title = title

doc = Document("Report.pdf")
print(doc.print_info())
print(doc.save())

# %% [markdown]
# ## Final Challenge: Library Management System

# %%
class Book:
    def __init__(self, title, author, isbn):
        self.title = title
        self.author = author
        self.isbn = isbn
        self.is_available = True
    
    def __str__(self):
        status = "Available" if self.is_available else "Borrowed"
        return f"'{self.title}' by {self.author} [{status}]"

class Member:
    def __init__(self, name, member_id):
        self.name = name
        self.member_id = member_id
        self.borrowed_books = []
    
    def __str__(self):
        return f"{self.name} (ID: {self.member_id}) - {len(self.borrowed_books)} books"

class Library:
    def __init__(self, name):
        self.name = name
        self._books = []
        self._members = []
    
    def add_book(self, book):
        self._books.append(book)
        return f"Added: {book.title}"
    
    def register_member(self, member):
        self._members.append(member)
        return f"Registered: {member.name}"
    
    def borrow_book(self, member_id, isbn):
        member = next((m for m in self._members if m.member_id == member_id), None)
        book = next((b for b in self._books if b.isbn == isbn), None)
        
        if not member:
            return "Member not found"
        if not book:
            return "Book not found"
        if not book.is_available:
            return "Book not available"
        
        book.is_available = False
        member.borrowed_books.append(book)
        return f"{member.name} borrowed '{book.title}'"
    
    def return_book(self, member_id, isbn):
        member = next((m for m in self._members if m.member_id == member_id), None)
        if not member:
            return "Member not found"
        
        book = next((b for b in member.borrowed_books if b.isbn == isbn), None)
        if not book:
            return "Book not borrowed by this member"
        
        book.is_available = True
        member.borrowed_books.remove(book)
        return f"{member.name} returned '{book.title}'"
    
    def __str__(self):
        return f"{self.name}: {len(self._books)} books, {len(self._members)} members"

# Test the system
lib = Library("City Library")

book1 = Book("Python Crash Course", "Eric Matthes", "001")
book2 = Book("Clean Code", "Robert Martin", "002")
print(lib.add_book(book1))
print(lib.add_book(book2))

member1 = Member("Alice", "M001")
print(lib.register_member(member1))

print(lib.borrow_book("M001", "001"))
print(book1)
print(lib.return_book("M001", "001"))
print(book1)
